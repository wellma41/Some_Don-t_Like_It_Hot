# %%
# Import our dependencies
import numpy as np
import pandas as pd
import tensorflow as tf
import re
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder

import os
import psycopg2 as psql  
 
DATABASE_URL = os.environ['postgresql-crystalline-35308']
  
conn = psql.connect(DATABASE_URL, sslmode='require')

data_get_query = 'select * from divorce_2010;'
divorce_2010_df = pd.read_sql(data_get_query, con = conn)

data_get_query = 'select * from divorce_2000;'
divorce_2000_df = pd.read_sql(data_get_query, con = conn)

data_get_query = 'select * from County_Temp;'
county_temp_df = pd.read_sql(data_get_query, con = conn)

data_get_query = 'select * from County_Precip;'
county_precip_df = pd.read_sql(data_get_query, con = conn)

conn.close()

# %%
dfp_2000 = county_precip_df.loc[county_precip_df['Year'] == 2000]
dfp_2010 = county_precip_df.loc[county_precip_df['Year'] == 2010]
dft_2000 = county_temp_df.loc[county_temp_df['Year'] == 2000]
dft_2010 = county_temp_df.loc[county_temp_df['Year'] == 2010]

dfp_2010.tail()
# Out:
#       index co_fips  Year  Days with > 0.1 inch of Precipitation  \
# 5466   5466   56037  2010                                   48.0
# 5467   5467   56039  2010                                   97.0
# 5468   5468   56041  2010                                   97.0
# 5469   5469   56043  2010                                   92.0
# 5470   5470   56045  2010                                   47.0
#
#       Extreme maximum precipitation  Days with snow depth > 1 inch
# 5466                       0.756667                      12.333333
# 5467                       1.260000                      42.666667
# 5468                       1.013333                      23.333333
# 5469                       1.340000                      19.000000
# 5470                       1.045000                      16.000000

# %%
div2010_temp_df = divorce_2010_df.merge(dft_2010,left_on='co_fips', right_on = 'co_fips', how='outer')
div2010_precip_df = divorce_2010_df.merge(dfp_2010,left_on='co_fips', right_on = 'co_fips', how='outer')
div2000_temp_df = divorce_2000_df.merge(dft_2000,left_on='co_fips', right_on = 'co_fips', how='outer')
div2000_precip_df = divorce_2000_df.merge(dfp_2000,left_on='co_fips', right_on = 'co_fips', how='outer')

div2000_precip_df.head()
# Out:
#   co_fips    Census  divorces     Geographic Area    year  index    Year  \
# 0   02013    2697.0       2.0  Aleutians East, AK  2000.0   59.0  2000.0
# 1   02016    5465.0      11.0  Aleutians West, AK  2000.0   60.0  2000.0
# 2   02020  260283.0    1301.0       Anchorage, AK  2000.0   61.0  2000.0
# 3   02050   16006.0      19.0          Bethel, AK  2000.0   62.0  2000.0
# 4   02060    1258.0       2.0     Bristol Bay, AK  2000.0   63.0  2000.0
#
#    Days with > 0.1 inch of Precipitation  Extreme maximum precipitation  \
# 0                                  260.0                       3.320000
# 1                                  172.0                       1.223333
# 2                                  217.0                       4.233333
# 3                                  143.0                       2.666667
# 4                                  142.0                       0.970000
#
#    Days with snow depth > 1 inch
# 0                      12.000000
# 1                      16.333333
# 2                      35.000000
# 3                      50.000000
# 4                      21.000000

# %%
div2000_precip_df = div2000_precip_df.drop(columns = ['Census','divorces','Geographic Area','year','index','Year'])

div2010_precip_df = div2010_precip_df.drop(columns = ['Census','divorces','Geographic Area','year','index','Year'])

div2000_weather_df = div2000_temp_df.merge(div2000_precip_df,left_on='co_fips', right_on = 'co_fips', how='outer')
div2010_weather_df = div2010_temp_df.merge(div2010_precip_df,left_on='co_fips', right_on = 'co_fips', how='outer')

div2000_weather_df = div2000_weather_df.drop(columns = ['Year','index'])
div2010_weather_df = div2010_weather_df.drop(columns = ['Year','index'])

div2010_weather_df
# Out:
#      co_fips  divorces Geographic Area  Census  year  Average Temp  \
# 0      01001       231     Autauga, AL   54571  2010           NaN
# 1      01003       980     Baldwin, AL  182265  2010          67.0
# 2      01005        69     Barbour, AL   27457  2010          67.0
# 3      01007        53        Bibb, AL   22915  2010          64.8
# 4      01009       258      Blount, AL   57322  2010           NaN
# ...      ...       ...             ...     ...   ...           ...
# 3137   56039        79       Teton, WY   21294  2010          38.7
# 3138   56041       128       Uinta, WY   21118  2010          40.3
# 3139   56043        43    Washakie, WY    8533  2010          41.1
# 3140   56045        31      Weston, WY    7208  2010          44.3
# 3141   51019       234     Bedford, VA   68676  2010           NaN
#
#       Days Over 90  Days Under 32  Days with > 0.1 inch of Precipitation  \
# 0              NaN            NaN                                   91.0
# 1        75.000000      22.000000                                  110.0
# 2       118.000000      33.333333                                    NaN
# 3        84.333333      59.666667                                   94.0
# 4              NaN            NaN                                  104.0
# ...            ...            ...                                    ...
# 3137      0.000000     206.666667                                   97.0
# 3138      4.666667     197.666667                                   97.0
# 3139     34.666667     177.000000                                   92.0
# 3140     46.666667     175.333333                                   47.0
# 3141           NaN            NaN                                  135.0
#
#       Extreme maximum precipitation  Days with snow depth > 1 inch
# 0                          3.025000                       0.000000
# 1                          3.515000                       0.000000
# 2                               NaN                            NaN
# 3                          3.925000                       0.000000
# 4                          7.605000                       0.000000
# ...                             ...                            ...
# 3137                       1.260000                      42.666667
# 3138                       1.013333                      23.333333
# 3139                       1.340000                      19.000000
# 3140                       1.045000                      16.000000
# 3141                       4.353333                       0.000000
#
# [3142 rows x 11 columns]

# %%
divorce_weather_df = div2000_weather_df.append(div2010_weather_df)


divorce_weather_df.tail()
# Out:
#      co_fips   Census  divorces Geographic Area    year  Average Temp  \
# 3137   56039  21294.0      79.0       Teton, WY  2010.0          38.7
# 3138   56041  21118.0     128.0       Uinta, WY  2010.0          40.3
# 3139   56043   8533.0      43.0    Washakie, WY  2010.0          41.1
# 3140   56045   7208.0      31.0      Weston, WY  2010.0          44.3
# 3141   51019  68676.0     234.0     Bedford, VA  2010.0           NaN
#
#       Days Over 90  Days Under 32  Days with > 0.1 inch of Precipitation  \
# 3137      0.000000     206.666667                                   97.0
# 3138      4.666667     197.666667                                   97.0
# 3139     34.666667     177.000000                                   92.0
# 3140     46.666667     175.333333                                   47.0
# 3141           NaN            NaN                                  135.0
#
#       Extreme maximum precipitation  Days with snow depth > 1 inch
# 3137                       1.260000                      42.666667
# 3138                       1.013333                      23.333333
# 3139                       1.340000                      19.000000
# 3140                       1.045000                      16.000000
# 3141                       4.353333                       0.000000

# %%
divorce_weather_df.dtypes
# Out:
# co_fips                                   object
# Census                                   float64
# divorces                                 float64
# Geographic Area                           object
# year                                     float64
# Average Temp                             float64
# Days Over 90                             float64
# Days Under 32                            float64
# Days with > 0.1 inch of Precipitation    float64
# Extreme maximum precipitation            float64
# Days with snow depth > 1 inch            float64
# dtype: object

# %%
# Drop the non-beneficial ID columns
clean_divorce_df = divorce_weather_df.drop(["co_fips", 'Geographic Area'], axis=1)

# %%
clean_divorce_df.dtypes
# Out:
# Census                                   float64
# divorces                                 float64
# year                                     float64
# Average Temp                             float64
# Days Over 90                             float64
# Days Under 32                            float64
# Days with > 0.1 inch of Precipitation    float64
# Extreme maximum precipitation            float64
# Days with snow depth > 1 inch            float64
# dtype: object

# %%
clean_divorce_df['divorce_rate_per_1000'] = (clean_divorce_df['divorces']/clean_divorce_df['Census']*1000).astype(float)
clean_divorce_df.drop(columns=['divorces'], inplace=True)

clean_divorce_df
# Out:
#         Census    year  Average Temp  Days Over 90  Days Under 32  \
# 0       2697.0  2000.0          38.7     18.666667     107.333333
# 1       5465.0  2000.0          36.5      0.000000     156.333333
# 2     260283.0  2000.0          38.7      0.000000     130.000000
# 3      16006.0  2000.0          30.6      0.000000     201.000000
# 4       1258.0  2000.0          35.1      0.000000     217.666667
# ...        ...     ...           ...           ...            ...
# 3137   21294.0  2010.0          38.7      0.000000     206.666667
# 3138   21118.0  2010.0          40.3      4.666667     197.666667
# 3139    8533.0  2010.0          41.1     34.666667     177.000000
# 3140    7208.0  2010.0          44.3     46.666667     175.333333
# 3141   68676.0  2010.0           NaN           NaN            NaN
#
#       Days with > 0.1 inch of Precipitation  Extreme maximum precipitation  \
# 0                                     260.0                       3.320000
# 1                                     172.0                       1.223333
# 2                                     217.0                       4.233333
# 3                                     143.0                       2.666667
# 4                                     142.0                       0.970000
# ...                                     ...                            ...
# 3137                                   97.0                       1.260000
# 3138                                   97.0                       1.013333
# 3139                                   92.0                       1.340000
# 3140                                   47.0                       1.045000
# 3141                                  135.0                       4.353333
#
#       Days with snow depth > 1 inch  divorce_rate_per_1000
# 0                         12.000000               0.741565
# 1                         16.333333               2.012809
# 2                         35.000000               4.998406
# 3                         50.000000               1.187055
# 4                         21.000000               1.589825
# ...                             ...                    ...
# 3137                      42.666667               3.709965
# 3138                      23.333333               6.061180
# 3139                      19.000000               5.039259
# 3140                      16.000000               4.300777
# 3141                       0.000000               3.407304
#
# [6285 rows x 9 columns]

# %%
clean_divorce_df.dropna()
# Out:
#         Census    year  Average Temp  Days Over 90  Days Under 32  \
# 0       2697.0  2000.0          38.7     18.666667     107.333333
# 1       5465.0  2000.0          36.5      0.000000     156.333333
# 2     260283.0  2000.0          38.7      0.000000     130.000000
# 3      16006.0  2000.0          30.6      0.000000     201.000000
# 4       1258.0  2000.0          35.1      0.000000     217.666667
# ...        ...     ...           ...           ...            ...
# 3136   43806.0  2010.0          43.7      3.333333     193.000000
# 3137   21294.0  2010.0          38.7      0.000000     206.666667
# 3138   21118.0  2010.0          40.3      4.666667     197.666667
# 3139    8533.0  2010.0          41.1     34.666667     177.000000
# 3140    7208.0  2010.0          44.3     46.666667     175.333333
#
#       Days with > 0.1 inch of Precipitation  Extreme maximum precipitation  \
# 0                                     260.0                       3.320000
# 1                                     172.0                       1.223333
# 2                                     217.0                       4.233333
# 3                                     143.0                       2.666667
# 4                                     142.0                       0.970000
# ...                                     ...                            ...
# 3136                                   48.0                       0.756667
# 3137                                   97.0                       1.260000
# 3138                                   97.0                       1.013333
# 3139                                   92.0                       1.340000
# 3140                                   47.0                       1.045000
#
#       Days with snow depth > 1 inch  divorce_rate_per_1000
# 0                         12.000000               0.741565
# 1                         16.333333               2.012809
# 2                         35.000000               4.998406
# 3                         50.000000               1.187055
# 4                         21.000000               1.589825
# ...                             ...                    ...
# 3136                      12.333333               5.113455
# 3137                      42.666667               3.709965
# 3138                      23.333333               6.061180
# 3139                      19.000000               5.039259
# 3140                      16.000000               4.300777
#
# [4709 rows x 9 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = clean_divorce_df["divorce_rate_per_1000"].values
X = clean_divorce_df.drop(["divorce_rate_per_1000"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# C:\Users\wobbi\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

number_input_features = len(X_train[0])
hidden_nodes_layer1 = 1000
hidden_nodes_layer2 = 1000


nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 1000)              9000
#
#  dense_19 (Dense)            (None, 1000)              1001000
#
#  dense_20 (Dense)            (None, 1)                 1001
#
# =================================================================
# Total params: 1,011,001
# Trainable params: 1,011,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 2/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 3/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 4/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 5/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 6/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 7/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 8/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191A: 0s - loss: nan -
# Epoch 9/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 10/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 11/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 12/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 13/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 14/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 15/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 16/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 17/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 18/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 19/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 20/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 21/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 22/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 23/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 24/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 25/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 26/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 27/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 28/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 29/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 30/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 31/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 32/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 33/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 34/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 35/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 36/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 37/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 38/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 39/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 40/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 41/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 42/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 43/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 44/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 45/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 46/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 47/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 48/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 49/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 50/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 51/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 52/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 53/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 54/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 55/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 56/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 57/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 58/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 59/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 60/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 61/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 62/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 63/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 64/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 65/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 66/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 67/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 68/100
# 148/148 [==============================] - 1s 5ms/step - loss: nan - accuracy: 0.0191
# Epoch 69/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 70/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 71/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 72/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 73/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 74/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 75/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 76/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 77/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 78/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 79/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 80/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 81/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 82/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 83/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191A: 0s - loss: nan - accuracy: 0.0
# Epoch 84/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 85/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 86/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 87/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 88/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 89/100
# 148/148 [==============================] - 1s 5ms/step - loss: nan - accuracy: 0.0191
# Epoch 90/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 91/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 92/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 93/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 94/100
# 148/148 [==============================] - 1s 5ms/step - loss: nan - accuracy: 0.0191
# Epoch 95/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 96/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191TA: 0s - loss: nan - accu
# Epoch 97/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 98/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 99/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191
# Epoch 100/100
# 148/148 [==============================] - 1s 6ms/step - loss: nan - accuracy: 0.0191

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 50/50 - 0s - loss: nan - accuracy: 0.0254 - 142ms/epoch - 3ms/step
# Loss: nan, Accuracy: 0.02544529177248478
