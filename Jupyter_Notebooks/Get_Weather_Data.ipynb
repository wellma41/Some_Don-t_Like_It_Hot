# %%
import pandas as pd
from config import NOAA_API_KEY
import requests
import json
# Out:
# CPQCozZPTrBtzHEedhAwYVNDRIjOFCFf

# %%
endpoint = "locationcategories"
api_url_base = f"https://www.ncdc.noaa.gov/cdo-web/api/v2/{endpoint}/id=CNTY?limit=100"
print(api_url_base)
r = requests.get(api_url_base, headers={'token':NOAA_API_KEY})
print(r.content)
# Out:
# https://www.ncdc.noaa.gov/cdo-web/api/v2/locationcategories/id=CNTY?limit=100
# b'{}'

# %%
# Out:
# https://www.ncdc.noaa.gov/cdo-web/api/v2/locationcategories/id=CNTY?limit=100/year=2000?fips=01001
# https://www.ncdc.noaa.gov/cdo-web/api/v2/locationcategories/id=CNTY?limit=100/year=2010?fips=01001
# https://www.ncdc.noaa.gov/cdo-web/api/v2/locationcategories/id=CNTY?limit=100/year=2000?fips=01003
# https://www.ncdc.noaa.gov/cdo-web/api/v2/locationcategories/id=CNTY?limit=100/year=2010?fips=01003
# https://www.ncdc.noaa.gov/cdo-web/api/v2/locationcategories/id=CNTY?limit=100/year=2000?fips=01005
# https://www.ncdc.noaa.gov/cdo-web/api/v2/locationcategories/id=CNTY?limit=100/year=2010?fips=01005
# https://www.ncdc.noaa.gov/cdo-web/api/v2/locationcategories/id=CNTY?limit=100/year=2000?fips=01007
# https://www.ncdc.noaa.gov/cdo-web/api/v2/locationcategories/id=CNTY?limit=100/year=2010?fips=01007
# https://www.ncdc.noaa.gov/cdo-web/api/v2/locationcategories/id=CNTY?limit=100/year=2000?fips=01009
# ...
